# %% [markdown]
# # 🧩 Plan de Práctica DSA para Científicos de Datos
# Este notebook contiene un plan progresivo de ejercicios de estructuras de datos y algoritmos (DSA) diseñado específicamente para Data Scientists.
#
# 📆 **Duración recomendada:** 4 semanas (1 hora diaria, 5 días por semana)
#
# ---
# ## 🟢 Nivel 1 – Fundamentos y velocidad lógica
# **Objetivo:** dominar estructuras básicas y la notación Big-O.
#
# ### 💡 Conceptos clave
# - Listas, slicing y bucles
# - Diccionarios y conteos (`collections.Counter`)
# - Conjuntos (`set`)
# - Complejidad temporal y espacial (Big-O)
#
# ### 📘 Ejercicios recomendados
# | Tema | Ejercicio | Nivel | Enlace |
# |------|------------|--------|--------|
# | Arrays | Two Sum | 🟢 Easy | https://leetcode.com/problems/two-sum/ |
# | Arrays | Best Time to Buy and Sell Stock | 🟢 Easy | https://leetcode.com/problems/best-time-to-buy-and-sell-stock/ |
# | HashMap | Contains Duplicate | 🟢 Easy | https://leetcode.com/problems/contains-duplicate/ |
# | Strings | Valid Anagram | 🟢 Easy | https://leetcode.com/problems/valid-anagram/ |
# | Strings | First Unique Character in a String | 🟢 Easy | https://leetcode.com/problems/first-unique-character-in-a-string/ |
#
# ---
# ## 🟠 Nivel 2 – Patrones y optimización
# **Objetivo:** aprender los patrones que más se repiten (two pointers, sliding window, recursion).
#
# ### 💡 Conceptos clave
# - Two Pointers y Sliding Window
# - Recursión básica
# - Pilas y colas (`collections.deque`)
# - Sorting y búsquedas binarias
# - Uso de `heapq`
#
# ### 📘 Ejercicios recomendados
# | Tema | Ejercicio | Nivel | Enlace |
# |------|------------|--------|--------|
# | Two Pointers | Move Zeroes | 🟢 Easy | https://leetcode.com/problems/move-zeroes/ |
# | Sliding Window | Longest Substring Without Repeating Characters | 🟠 Medium | https://leetcode.com/problems/longest-substring-without-repeating-characters/ |
# | Stack | Valid Parentheses | 🟢 Easy | https://leetcode.com/problems/valid-parentheses/ |
# | Sorting | Merge Intervals | 🟠 Medium | https://leetcode.com/problems/merge-intervals/ |
# | Heap | Kth Largest Element in an Array | 🟠 Medium | https://leetcode.com/problems/kth-largest-element-in-an-array/ |
# | Binary Search | Search Insert Position | 🟢 Easy | https://leetcode.com/problems/search-insert-position/ |
#
# ---
# ## 🔵 Nivel 3 – Pensamiento algorítmico y estructuras avanzadas
# **Objetivo:** resolver problemas complejos (grafos, DP, árboles, combinatoria).
#
# ### 💡 Conceptos clave
# - Árboles y grafos (DFS, BFS)
# - Backtracking
# - Dynamic Programming (DP)
# - Problemas combinatorios
#
# ### 📘 Ejercicios recomendados
# | Tema | Ejercicio | Nivel | Enlace |
# |------|------------|--------|--------|
# | Árboles | Maximum Depth of Binary Tree | 🟢 Easy | https://leetcode.com/problems/maximum-depth-of-binary-tree/ |
# | Grafos | Number of Islands | 🟠 Medium | https://leetcode.com/problems/number-of-islands/ |
# | Backtracking | Subsets | 🟠 Medium | https://leetcode.com/problems/subsets/ |
# | Dynamic Programming | Climbing Stairs | 🟢 Easy | https://leetcode.com/problems/climbing-stairs/ |
# | Dynamic Programming | House Robber | 🟠 Medium | https://leetcode.com/problems/house-robber/ |
#
# ---
# ## 🧠 Consejo final
# - No necesitas resolver cientos de ejercicios, sino **entender 40-50 a fondo**.
# - Practica explicando tus soluciones en voz alta.
# - Justifica siempre la complejidad temporal y espacial.
#
# 💡 Usa las celdas de código debajo para implementar tus soluciones y medir tiempos con `%timeit`.

# %%
# ✍️ Aquí puedes escribir tu solución para el primer ejercicio: Two Sum
from typing import List

def two_sum(nums: List[int], target: int) -> List[int]:
    lookup = {}
    for i, num in enumerate(nums):
        complement = target - num
        if complement in lookup:
            return [lookup[complement], i]
        lookup[num] = i

# Ejemplo de prueba
two_sum([2, 7, 11, 15], 9)

# %%
# ⏱️ Mide el tiempo de ejecución
# %timeit two_sum([2, 7, 11, 15], 9)
